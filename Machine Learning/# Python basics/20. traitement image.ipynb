# %% [markdown]
# # Introduction au traitement d'image
#
# image = tableau de nombre où chaque case contient l'intensité d'un pixel.
#
#
# intensité du pixel : controle l'allumage de la "diode" à l'écran.
#
# 0 = noir
# 255 = Blanc ou couleur

# %%
# !pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 49.5 MB 29.8 MB/s
# ...
# WARNING: You are using pip version 20.2.4; however, version 20.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
import cv2

# %%
img = cv2.imread('2290.jpg') # charge dans l'ordre BGR (pas le truc standard)
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
img.shape
# Out:
# (1200, 1200, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img[500:800, :, :] = 255
img[:, 600:800, :] = 0

# %%
plt.imshow(img)

# %%
img[:, :, 0] = 255
plt.imshow(img)

# %%
rotated = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
plt.imshow(rotated)

# %%
img = cv2.imread('2290.jpg') # charge dans l'ordre BGR (pas le truc standard)

img.shape
# Out:
# (1200, 1200, 3)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap="gray")

# %%
gray_myself = np.mean(img, axis=2)
plt.imshow(gray_myself, cmap="gray")

# %%
gray.shape
# Out:
# (1200, 1200)

# %%
gray[500:550, 500:505]
# Out:
# array([[191, 185, 206, 214, 184],
#        [188, 196, 206, 200, 177],
#        [186, 209, 205, 184, 176],
#        [182, 212, 199, 169, 178],
#        [193, 202, 186, 173, 157],
#        [191, 200, 178, 160, 153],
#        [193, 200, 169, 141, 147],
#        [195, 190, 152, 125, 152],
#        [189, 163, 129, 115, 174],
#        [170, 136, 120, 123, 198],
#        [145, 132, 142, 153, 199],
#        [128, 143, 172, 183, 187],
#        [162, 184, 151, 167, 189],
#        [175, 173, 143, 173, 183],
#        [169, 152, 142, 191, 182],
#        [153, 136, 150, 205, 189],
#        [148, 133, 160, 209, 192],
#        [142, 131, 164, 222, 180],
#        [127, 126, 158, 236, 159],
#        [116, 124, 145, 235, 143],
#        [114, 113, 156, 241, 137],
#        [117, 114, 162, 242, 132],
#        [117, 110, 169, 241, 128],
#        [111, 101, 179, 238, 123],
#        [102,  94, 193, 233, 113],
#        [ 90,  91, 209, 222,  99],
#        [ 75,  89, 219, 206,  90],
# ...

# %%
#threshold 
gray[gray > 180] = 255
gray[gray <= 180] = 0 


plt.imshow(gray, cmap="gray")

# %%
cv2.thresold()


#convolution !

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=25ad01f7-ec4b-4ac8-bce6-a3745ef02c96' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
